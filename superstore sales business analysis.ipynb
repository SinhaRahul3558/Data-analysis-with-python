# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
import warnings
warnings.simplefilter("ignore")
sns.set_theme(style='darkgrid')
f2 = {"family":"cambria","color":"g","size":50}
f3  = {"family":"cambria","color":"k","size":40}
f1 = {"family":"cambria","color":"r","size":30}

# %%
df1 = pd.read_csv(r"C:\Users\Sinha Rahul\Downloads\archive (6).zip")

# %%
df1
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  6/1/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  5/1/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  5/1/2011    Second Class
# 4        IN-2011-47883    1/1/2011  8/1/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286     MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287   MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288   MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289   CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Draâ        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ...         category sub_category  \
# 0       Africa  ...  Office Supplies      Storage
# 1      Oceania  ...  Office Supplies     Supplies
# 2         EMEA  ...  Office Supplies      Storage
# 3        North  ...  Office Supplies        Paper
# 4      Oceania  ...        Furniture  Furnishings
# ...        ...  ...              ...          ...
# 51285     West  ...  Office Supplies      Binders
# 51286   Africa  ...  Office Supplies      Binders
# 51287  Central  ...  Office Supplies       Labels
# 51288    North  ...  Office Supplies       Labels
# 51289     West  ...  Office Supplies    Fasteners
#
#                                           product_name sales quantity  \
# 0                                  Tenex Lockers, Blue   408        2
# 1                             Acme Trimmer, High Speed   120        3
# 2                              Tenex Box, Single Width    66        4
# 3                          Enermax Note Cards, Premium    45        3
# 4                           Eldon Light Bulb, Duo Pack   114        5
# ...                                                ...   ...      ...
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14        2
# 51286          Wilson Jones Hole Reinforcements, Clear     4        1
# 51287           Hon Color Coded Labels, 5000 Label Set    26        3
# 51288           Hon Legal Exhibit Labels, Alphabetical     7        1
# 51289                              Bagged Rubber Bands     3        3
#
#        discount    profit  shipping_cost  order_priority  year
# 0           0.0  106.1400          35.46          Medium  2011
# 1           0.1   36.0360           9.72          Medium  2011
# 2           0.0   29.6400           8.17            High  2011
# 3           0.5  -26.0550           4.82            High  2011
# 4           0.1   37.7700           4.70          Medium  2011
# ...         ...       ...            ...             ...   ...
# 51285       0.2    4.5188           0.89          Medium  2014
# 51286       0.0    0.4200           0.49          Medium  2014
# 51287       0.0   12.3600           0.35          Medium  2014
# 51288       0.0    0.5600           0.20          Medium  2014
# 51289       0.2   -0.6048           0.17          Medium  2014
#
# [51290 rows x 21 columns]

# %% [markdown]
# # Display Top 10 row in dataset

# %%
df1.head(10)
# Out:
#           order_id order_date ship_date       ship_mode     customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class   Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class       Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class     Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class      Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class       Joseph Holt
# 5    IN-2011-47883   1/1/2011  8/1/2011  Standard Class       Joseph Holt
# 6     CA-2011-1510   2/1/2011  6/1/2011  Standard Class   Magdelene Morse
# 7    IN-2011-79397   3/1/2011  3/1/2011        Same Day       Kean Nguyen
# 8    ID-2011-80230   3/1/2011  9/1/2011  Standard Class      Ken Lonsdale
# 9     IZ-2011-4680   3/1/2011  7/1/2011  Standard Class  Lindsay Williams
#
#        segment            state      country  market   region  ...  \
# 0     Consumer      Constantine      Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales    Australia    APAC  Oceania  ...
# 2     Consumer         Budapest      Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm       Sweden      EU    North  ...
# 4     Consumer  New South Wales    Australia    APAC  Oceania  ...
# 5     Consumer  New South Wales    Australia    APAC  Oceania  ...
# 6     Consumer          Ontario       Canada  Canada   Canada  ...
# 7    Corporate  New South Wales    Australia    APAC  Oceania  ...
# 8     Consumer         Auckland  New Zealand    APAC  Oceania  ...
# 9    Corporate           Ninawa         Iraq    EMEA     EMEA  ...
#
#           category sub_category                             product_name  \
# 0  Office Supplies      Storage                      Tenex Lockers, Blue
# 1  Office Supplies     Supplies                 Acme Trimmer, High Speed
# 2  Office Supplies      Storage                  Tenex Box, Single Width
# 3  Office Supplies        Paper              Enermax Note Cards, Premium
# 4        Furniture  Furnishings               Eldon Light Bulb, Duo Pack
# 5  Office Supplies        Paper  Eaton Computer Printout Paper, 8.5 x 11
# 6       Technology     Machines                 Okidata Inkjet, Wireless
# 7  Office Supplies   Appliances                  Hoover Microwave, White
# 8       Technology      Copiers              Hewlett Wireless Fax, Laser
# 9        Furniture       Chairs         Novimex Swivel Stool, Set of Two
#
#   sales quantity  discount   profit  shipping_cost  order_priority  year
# 0   408        2       0.0  106.140          35.46          Medium  2011
# 1   120        3       0.1   36.036           9.72          Medium  2011
# 2    66        4       0.0   29.640           8.17            High  2011
# 3    45        3       0.5  -26.055           4.82            High  2011
# 4   114        5       0.1   37.770           4.70          Medium  2011
# 5    55        2       0.1   15.342           1.80          Medium  2011
# 6   314        1       0.0    3.120          24.10          Medium  2011
# 7   276        1       0.1  110.412         125.32        Critical  2011
# 8   912        4       0.4 -319.464         107.10             Low  2011
# 9   667        4       0.0  253.320          81.26            High  2011
#
# [10 rows x 21 columns]

# %% [markdown]
# # Display tail 10 row in dataset

# %%
df1.tail(10)
# Out:
#              order_id  order_date ship_date       ship_mode  \
# 51280    TZ-2014-8220  31-12-2014  6/1/2015  Standard Class
# 51281  CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51282    UP-2014-4410  31-12-2014  4/1/2015  Standard Class
# 51283   IN-2014-23754  31-12-2014  7/1/2015  Standard Class
# 51284  MX-2014-108574  31-12-2014  4/1/2015  Standard Class
# 51285  CA-2014-115427  31-12-2014  4/1/2015  Standard Class
# 51286    MO-2014-2560  31-12-2014  5/1/2015  Standard Class
# 51287  MX-2014-110527  31-12-2014  2/1/2015    Second Class
# 51288  MX-2014-114783  31-12-2014  6/1/2015  Standard Class
# 51289  CA-2014-156720  31-12-2014  4/1/2015  Standard Class
#
#             customer_name      segment             state        country  \
# 51280  Christine Kargatis  Home Office     Dar Es Salaam       Tanzania
# 51281          Erica Bern    Corporate        California  United States
# 51282        Guy Thornton     Consumer      Zaporizhzhya        Ukraine
# 51283        Kalyca Meade    Corporate         Guangdong          China
# 51284       Julia Barnett  Home Office        Tamaulipas         Mexico
# 51285          Erica Bern    Corporate        California  United States
# 51286           Liz Preis     Consumer  Souss-Massa-Draâ        Morocco
# 51287    Charlotte Melton     Consumer           Managua      Nicaragua
# 51288       Tamara Dahlen     Consumer         Chihuahua         Mexico
# 51289       Jill Matthias     Consumer          Colorado  United States
#
#        market      region  ...         category sub_category  \
# 51280  Africa      Africa  ...  Office Supplies       Labels
# 51281      US        West  ...  Office Supplies      Binders
# 51282    EMEA        EMEA  ...  Office Supplies       Labels
# 51283    APAC  North Asia  ...  Office Supplies        Paper
# 51284   LATAM       North  ...  Office Supplies       Labels
# 51285      US        West  ...  Office Supplies      Binders
# 51286  Africa      Africa  ...  Office Supplies      Binders
# 51287   LATAM     Central  ...  Office Supplies       Labels
# 51288   LATAM       North  ...  Office Supplies       Labels
# 51289      US        West  ...  Office Supplies    Fasteners
#
#                                           product_name sales quantity  \
# 51280   Harbour Creations Removable Labels, Adjustable    50        6
# 51281                               GBC Binding covers    21        2
# 51282                 Avery Round Labels, Alphabetical    28        4
# 51283                       Eaton Note Cards, 8.5 x 11    79        3
# 51284         Novimex Legal Exhibit Labels, Adjustable    17        3
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14        2
# 51286          Wilson Jones Hole Reinforcements, Clear     4        1
# 51287           Hon Color Coded Labels, 5000 Label Set    26        3
# 51288           Hon Legal Exhibit Labels, Alphabetical     7        1
# 51289                              Bagged Rubber Bands     3        3
#
#        discount   profit  shipping_cost  order_priority  year
# 51280       0.0   6.8400           2.15          Medium  2014
# 51281       0.2   6.4750           2.06          Medium  2014
# 51282       0.0   6.1200           1.70          Medium  2014
# 51283       0.0  25.3800           1.41          Medium  2014
# 51284       0.0   0.6600           1.32          Medium  2014
# 51285       0.2   4.5188           0.89          Medium  2014
# 51286       0.0   0.4200           0.49          Medium  2014
# 51287       0.0  12.3600           0.35          Medium  2014
# 51288       0.0   0.5600           0.20          Medium  2014
# 51289       0.2  -0.6048           0.17          Medium  2014
#
# [10 rows x 21 columns]

# %% [markdown]
# # Find the shape of our dataset(number of column & number of row)

# %%
df1.shape
# Out:
# (51290, 21)

# %%
print("number of column is",df1.shape[0])
# Out:
# number of column is 51290

# %%
print("number of row is",df1.shape[1])
# Out:
# number of row is 21

# %% [markdown]
# # Find the size of our dataset

# %%
df1.size
# Out:
# 1077090

# %% [markdown]
# # Getting information about our dataset likes total number of rows, total number of columns,data type of each column and memory requirement

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
#  18  shipping_cost   51290 non-null  float64
#  19  order_priority  51290 non-null  object
#  20  year            51290 non-null  int64
# dtypes: float64(3), int64(2), object(16)
# memory usage: 8.2+ MB

# %%
df1.info( memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
#  18  shipping_cost   51290 non-null  float64
#  19  order_priority  51290 non-null  object
#  20  year            51290 non-null  int64
# dtypes: float64(3), int64(2), object(16)
# memory usage: 55.0 MB

# %% [markdown]
# # Changing the Incorrect Data Types

# %%
df1["order_date"] = df1["order_date"].astype('datetime64[ns]')
df1["ship_date"] = df1["ship_date"].astype("datetime64[ns]")
df1['sales'] = pd.to_numeric(df1['sales'], errors= "coerce")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  datetime64[ns]
#  2   ship_date       51290 non-null  datetime64[ns]
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           48660 non-null  float64
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
#  18  shipping_cost   51290 non-null  float64
#  19  order_priority  51290 non-null  object
#  20  year            51290 non-null  int64
# dtypes: datetime64[ns](2), float64(4), int64(2), object(13)
# memory usage: 8.2+ MB

# %% [markdown]
# # check missing value in dataset

# %%
df1.isnull().values.any()
# Out:
# True

# %% [markdown]
# # check duplicate value in dataset

# %%
df1.duplicated().values.any()
# Out:
# False

# %% [markdown]
# # Get overall statistics about the dataframe

# %%
df1.describe()
# Out:
#               sales      quantity      discount        profit  shipping_cost  \
# count  48660.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     161.017838      3.476545      0.142908     28.641740      26.375915
# std      201.092519      2.278766      0.212280    174.424113      57.296804
# min        0.000000      1.000000      0.000000  -6599.978000       0.000000
# 25%       29.000000      2.000000      0.000000      0.000000       2.610000
# 50%       77.000000      3.000000      0.000000      9.240000       7.790000
# 75%      208.000000      5.000000      0.200000     36.810000      24.450000
# max      999.000000     14.000000      0.850000   8399.976000     933.570000
#
#                year
# count  51290.000000
# mean    2012.777208
# std        1.098931
# min     2011.000000
# 25%     2012.000000
# 50%     2013.000000
# 75%     2014.000000
# max     2014.000000

# %% [markdown]
# # correlation

# %%
df1.corr()
# Out:
#                   sales  quantity  discount    profit  shipping_cost      year
# sales          1.000000  0.276072 -0.106719  0.252703       0.771133 -0.002479
# quantity       0.276072  1.000000 -0.019875  0.104743       0.272649 -0.005049
# discount      -0.106719 -0.019875  1.000000 -0.316375      -0.079056 -0.005894
# profit         0.252703  0.104743 -0.316375  1.000000       0.357033  0.002661
# shipping_cost  0.771133  0.272649 -0.079056  0.357033       1.000000 -0.003136
# year          -0.002479 -0.005049 -0.005894  0.002661      -0.003136  1.000000

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df1.corr(),annot = True)
plt.show()

# %% [markdown]
# # EDA

# %% [markdown]
# # Q1: Which segment is the best seller?

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["segment"].unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %%
plt.figure(figsize=(7,12))
sns.countplot(df1["segment"])
plt.show()

# %% [markdown]
# # Q2: Which Region has the highest order count and In which Region do we need to grow our Business?¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["region"].unique()
# Out:
# array(['Africa', 'Oceania', 'EMEA', 'North', 'Canada', 'Southeast Asia',
#        'Central', 'South', 'Caribbean', 'North Asia', 'East', 'West',
#        'Central Asia'], dtype=object)

# %%
plt.figure(figsize=(12,10))
sns.countplot(df1["region"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Q3: Who are the Top 10 Customers of the SuperStore and How much is their Repartition of the Profit?¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["customer_name"].nunique()
# Out:
# 795

# %%
df2 = df1.groupby("customer_name")["profit"].sum().reset_index()
df3 = df2.sort_values(by = "profit",ascending=False).head(10).round(0)
df3
# Out:
#        customer_name  profit
# 731     Tamara Chand  8673.0
# 623     Raymond Buch  8453.0
# 672     Sanjit Chand  8205.0
# 335     Hunter Lopez  7817.0
# 88       Bill Eplett  7410.0
# 323      Harry Marie  6958.0
# 727     Susan Pistek  6484.0
# 542  Mike Gockenbach  6459.0
# 6      Adrian Barton  6417.0
# 758     Tom Ashbrook  6312.0

# %%
plt.figure(figsize=(12,10))
sns.barplot(x = "customer_name",y = "profit", data = df3)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # How much each Sub-Category is contributing in Sales of SuperStore?

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["sub_category"].unique()
# Out:
# array(['Storage', 'Supplies', 'Paper', 'Furnishings', 'Machines',
#        'Appliances', 'Copiers', 'Chairs', 'Tables', 'Bookcases', 'Phones',
#        'Accessories', 'Labels', 'Art', 'Envelopes', 'Fasteners',
#        'Binders'], dtype=object)

# %%
df4 = df1.groupby("sub_category")["sales"].count().reset_index()
df4
# Out:
#    sub_category  sales
# 0   Accessories   2956
# 1    Appliances   1427
# 2           Art   4882
# 3       Binders   6108
# 4     Bookcases   2031
# 5        Chairs   3105
# 6       Copiers   1810
# 7     Envelopes   2435
# 8     Fasteners   2420
# 9   Furnishings   3163
# 10       Labels   2606
# 11     Machines   1302
# 12        Paper   3538
# 13       Phones   2950
# 14      Storage   4903
# 15     Supplies   2417
# 16       Tables    607

# %%
plt.figure(figsize=(12,15))
sns.barplot(x = "sub_category", y = "sales", data= df4,saturation=0.65)
plt.xticks(rotation = 75)
plt.show()

# %% [markdown]
# # OR

# %%
plt.figure(figsize=(12,15))
sns.countplot(df1["sub_category"])
plt.xticks(rotation = 75)
plt.show()

# %% [markdown]
# # What are the Top 10 States with highest Order Count?¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["state"].nunique()
# Out:
# 1094

# %%
df5 = df1.groupby("state")["sales"].count().sort_values(ascending=False).head(10).reset_index()
df5
# Out:
#                     state  sales
# 0              California   1901
# 1                 England   1388
# 2                New York   1060
# 3                   Texas    959
# 4           Ile-de-France    900
# 5         New South Wales    715
# 6  North Rhine-Westphalia    670
# 7              Queensland    659
# 8            San Salvador    586
# 9            Pennsylvania    565

# %% [markdown]
# #    # Look for Top 10 Consumer Countries is contributing in sales of supermarket

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["country"].unique()
# Out:
# array(['Algeria', 'Australia', 'Hungary', 'Sweden', 'Canada',
#        'New Zealand', 'Iraq', 'Philippines', 'United Kingdom', 'Malaysia',
#        'Guatemala', 'Iran', 'Thailand', 'Tanzania', 'Brazil', 'Mexico',
#        'Cuba', 'France', 'United States', 'Japan', 'Sudan', 'Taiwan',
#        'Indonesia', 'Vietnam', 'Angola', 'China', 'Mozambique', 'Lebanon',
#        'Singapore', 'Netherlands', 'Nigeria', 'Egypt', 'Venezuela',
#        'South Africa', 'Spain', 'India', 'Turkey', 'Austria', 'Italy',
#        'Germany', 'Nicaragua', 'Dominican Republic', 'El Salvador',
#        'Denmark', 'Saudi Arabia', 'Zambia', 'Myanmar (Burma)', 'Russia',
#        'Mongolia', 'Belgium', 'Kenya', 'Colombia', 'Estonia',
#        'Madagascar', 'Portugal', 'Morocco', 'Sierra Leone', 'Norway',
#        'Central African Republic', 'Czech Republic', 'Benin',
#        'Bangladesh', 'Panama', 'Chile', 'South Korea', 'Switzerland',
#        'Moldova', 'Uganda', 'Zimbabwe', 'Niger', 'Senegal', 'Hong Kong',
#        'Democratic Republic of the Congo', 'Poland', 'Ireland',
#        'Pakistan', 'Azerbaijan', 'Ukraine', 'Albania', 'Romania',
#        'Honduras', 'Israel', 'Cameroon', 'Cambodia', 'Georgia',
#        'Argentina', 'Finland', 'Lithuania', 'Peru', 'Somalia', 'Haiti',
#        "Cote d'Ivoire", 'Afghanistan', 'Guinea', 'Liberia', 'South Sudan',
#        'Turkmenistan', 'Kazakhstan', 'Lesotho', 'Burundi', 'Qatar',
#        'Bulgaria', 'Martinique', 'Croatia', 'Ghana', 'Rwanda', 'Ecuador',
#        'Paraguay', 'Ethiopia', 'Syria', 'Tajikistan', 'Slovakia',
#        'Belarus', 'Papua New Guinea', 'Togo', 'Libya', 'Djibouti',
#        'Yemen', 'United Arab Emirates', 'Barbados', 'Uzbekistan',
#        'Jamaica', 'Bolivia', 'Uruguay', 'Republic of the Congo',
#        'Swaziland', 'Kyrgyzstan', 'Guinea-Bissau',
#        'Bosnia and Herzegovina', 'Tunisia', 'Armenia', 'Mali', 'Jordan',
#        'Trinidad and Tobago', 'Namibia', 'Gabon', 'Macedonia', 'Nepal',
#        'Mauritania', 'Guadeloupe', 'Sri Lanka', 'Chad', 'Eritrea',
#        'Bahrain', 'Equatorial Guinea', 'Slovenia', 'Montenegro'],
#       dtype=object)

# %%
df7 = df1.groupby("country")["sales"].count().sort_values(ascending=False).head(10)
df8 = df7.reset_index()
df8
# Out:
#           country  sales
# 0   United States   9523
# 1          France   2626
# 2       Australia   2623
# 3          Mexico   2514
# 4         Germany   1928
# 5           China   1696
# 6          Brazil   1530
# 7  United Kingdom   1512
# 8           India   1411
# 9          Turkey   1367

# %% [markdown]
# # Look for Top 10 Consumer Countries is contributing in profit of supermarket

# %%
df9 = df1.groupby("country")["profit"].sum().sort_values(ascending=False).head(10).reset_index()
df9
# Out:
#           country        profit
# 0   United States  286397.02170
# 1           China  150683.08500
# 2           India  129071.83500
# 3  United Kingdom  111900.15000
# 4          France  109029.00300
# 5         Germany  107322.82050
# 6       Australia  105484.96300
# 7          Mexico  102818.09752
# 8           Spain   54390.12000
# 9     El Salvador   42023.24320

# %% [markdown]
# # What are the Top 3 Consumer Countries orders as per Segment & Category?

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["segment"].unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %%
df1["category"].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
df9 = df1["country"].value_counts().head(3).reset_index().rename(columns = {"index":"country",
                                                                           "country":"count_sales"})
df9
# Out:
#          country  count_sales
# 0  United States         9994
# 1      Australia         2837
# 2         France         2827

# %%
plt.figure(figsize=(15,10))
plt.title("United States",fontdict=f1)
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["category"])
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title("Australia",fontdict=f1)
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["category"])
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.title("France",fontdict=f1)
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["category"])
plt.show()

# %% [markdown]
# # What are the product needs of Top 3 countries as per Category & Sub-category?

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
plt.title("United States",fontdict=f1)
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["category"],hue=df1["sub_category"])
plt.show()


plt.figure(figsize=(15,10))
plt.title("United States",fontdict=f1)
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["category"],hue=df1["sub_category"])
plt.show()



plt.figure(figsize=(15,10))
plt.title("United States",fontdict=f1)
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["category"],hue=df1["sub_category"])
plt.show()

# %% [markdown]
# # Growth of Superstore Sales over the year 2011-2014?¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["year"].unique()
# Out:
# array([2011, 2012, 2013, 2014], dtype=int64)

# %%
df11 = df1.groupby("year")["sales"].sum().reset_index()
df11
# Out:
#    year      sales
# 0  2011  1378151.0
# 1  2012  1681499.0
# 2  2013  2107021.0
# 3  2014  2668457.0

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = "year", y = "sales", data= df11,saturation=0.65)
plt.xticks(rotation = 75)
plt.title("Growth of the Store",fontdict=f1)
plt.show()

# %% [markdown]
# # Growth of Superstore quantity over the year 2011-2014?¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["year"].unique()
# Out:
# array([2011, 2012, 2013, 2014], dtype=int64)

# %%
df12 = df1.groupby("year")["quantity"].sum().reset_index()
df12
# Out:
#    year  quantity
# 0  2011     31443
# 1  2012     38111
# 2  2013     48136
# 3  2014     60622

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = "year", y = "quantity", data= df12,saturation=0.65)
plt.xticks(rotation = 75)
plt.title("Growth of the Store",fontdict=f1)
plt.show()

# %% [markdown]
# # Analyzing Profit category and sub_category wise

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df13 = df1.groupby(["category","sub_category"])["profit"].sum().reset_index()
df13
# Out:
#            category sub_category        profit
# 0         Furniture    Bookcases  161924.41950
# 1         Furniture       Chairs  141973.79750
# 2         Furniture  Furnishings   46967.42550
# 3         Furniture       Tables  -64083.38870
# 4   Office Supplies   Appliances  141680.58940
# 5   Office Supplies          Art   57953.91090
# 6   Office Supplies      Binders   72449.84600
# 7   Office Supplies    Envelopes   29601.11630
# 8   Office Supplies    Fasteners   11525.42410
# 9   Office Supplies       Labels   15010.51200
# 10  Office Supplies        Paper   59207.68270
# 11  Office Supplies      Storage  108461.48980
# 12  Office Supplies     Supplies   22583.26310
# 13       Technology  Accessories  129626.30620
# 14       Technology      Copiers  258567.54818
# 15       Technology     Machines   58867.87300
# 16       Technology       Phones  216717.00580

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = "category", y = "profit", data= df13,saturation=0.65, hue = "sub_category")
plt.xticks(rotation = 75)
plt.title("Growth of the Store",fontdict=f1)
plt.show()

# %% [markdown]
# # Analyzing Profit from each Market in the World

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["market"].unique()
# Out:
# array(['Africa', 'APAC', 'EMEA', 'EU', 'Canada', 'LATAM', 'US'],
#       dtype=object)

# %%
df14 = df1.groupby(["segment","market"])["profit"].sum().reset_index()
df14
# Out:
#         segment  market        profit
# 0      Consumer    APAC  222817.56040
# 1      Consumer  Africa   47772.09900
# 2      Consumer  Canada    9677.70000
# 3      Consumer    EMEA   25532.57400
# 4      Consumer      EU  188687.70750
# 5      Consumer   LATAM  120632.93196
# 6      Consumer      US  134119.20920
# 7     Corporate    APAC  131314.76480
# 8     Corporate  Africa   20686.96500
# 9     Corporate  Canada    5036.46000
# 10    Corporate    EMEA   12499.13400
# 11    Corporate      EU  123393.97950
# 12    Corporate   LATAM   57875.42136
# 13    Corporate      US   91979.13400
# 14  Home Office    APAC   83445.25380
# 15  Home Office  Africa   20412.56700
# 16  Home Office  Canada    3103.23000
# 17  Home Office    EMEA    5866.26300
# 18  Home Office      EU   60748.05450
# 19  Home Office   LATAM   43135.13376
# 20  Home Office      US   60298.67850

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = "market", y = "profit", data= df14,saturation=0.65, hue = "segment")
plt.xticks(rotation = 75)
plt.title("Growth of the Store",fontdict=f1)
plt.show()

# %% [markdown]
# # Analyzing sales from each Market in the World

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df14 = df1.groupby("market")["sales"].sum().reset_index()
df14
# Out:
#    market      sales
# 0    APAC  2000746.0
# 1  Africa   538115.0
# 2  Canada    50314.0
# 3    EMEA   575562.0
# 4      EU  1803099.0
# 5   LATAM  1563126.0
# 6      US  1304166.0

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = "market", y = "sales", data= df14,saturation=0.65)
plt.xticks(rotation = 75)
plt.title("Growth of the Store",fontdict=f1)
plt.show()

# %% [markdown]
# # Top 5 Profitable Countries?

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["country"].unique()
# Out:
# array(['Algeria', 'Australia', 'Hungary', 'Sweden', 'Canada',
#        'New Zealand', 'Iraq', 'Philippines', 'United Kingdom', 'Malaysia',
#        'Guatemala', 'Iran', 'Thailand', 'Tanzania', 'Brazil', 'Mexico',
#        'Cuba', 'France', 'United States', 'Japan', 'Sudan', 'Taiwan',
#        'Indonesia', 'Vietnam', 'Angola', 'China', 'Mozambique', 'Lebanon',
#        'Singapore', 'Netherlands', 'Nigeria', 'Egypt', 'Venezuela',
#        'South Africa', 'Spain', 'India', 'Turkey', 'Austria', 'Italy',
#        'Germany', 'Nicaragua', 'Dominican Republic', 'El Salvador',
#        'Denmark', 'Saudi Arabia', 'Zambia', 'Myanmar (Burma)', 'Russia',
#        'Mongolia', 'Belgium', 'Kenya', 'Colombia', 'Estonia',
#        'Madagascar', 'Portugal', 'Morocco', 'Sierra Leone', 'Norway',
#        'Central African Republic', 'Czech Republic', 'Benin',
#        'Bangladesh', 'Panama', 'Chile', 'South Korea', 'Switzerland',
#        'Moldova', 'Uganda', 'Zimbabwe', 'Niger', 'Senegal', 'Hong Kong',
#        'Democratic Republic of the Congo', 'Poland', 'Ireland',
#        'Pakistan', 'Azerbaijan', 'Ukraine', 'Albania', 'Romania',
#        'Honduras', 'Israel', 'Cameroon', 'Cambodia', 'Georgia',
#        'Argentina', 'Finland', 'Lithuania', 'Peru', 'Somalia', 'Haiti',
#        "Cote d'Ivoire", 'Afghanistan', 'Guinea', 'Liberia', 'South Sudan',
#        'Turkmenistan', 'Kazakhstan', 'Lesotho', 'Burundi', 'Qatar',
#        'Bulgaria', 'Martinique', 'Croatia', 'Ghana', 'Rwanda', 'Ecuador',
#        'Paraguay', 'Ethiopia', 'Syria', 'Tajikistan', 'Slovakia',
#        'Belarus', 'Papua New Guinea', 'Togo', 'Libya', 'Djibouti',
#        'Yemen', 'United Arab Emirates', 'Barbados', 'Uzbekistan',
#        'Jamaica', 'Bolivia', 'Uruguay', 'Republic of the Congo',
#        'Swaziland', 'Kyrgyzstan', 'Guinea-Bissau',
#        'Bosnia and Herzegovina', 'Tunisia', 'Armenia', 'Mali', 'Jordan',
#        'Trinidad and Tobago', 'Namibia', 'Gabon', 'Macedonia', 'Nepal',
#        'Mauritania', 'Guadeloupe', 'Sri Lanka', 'Chad', 'Eritrea',
#        'Bahrain', 'Equatorial Guinea', 'Slovenia', 'Montenegro'],
#       dtype=object)

# %%
df16 = df1.groupby("country")["profit"].sum().sort_values(ascending = False).reset_index().head(5)
df16
# Out:
#           country       profit
# 0   United States  286397.0217
# 1           China  150683.0850
# 2           India  129071.8350
# 3  United Kingdom  111900.1500
# 4          France  109029.0030

# %%
plt.figure(figsize=(15,10))
sns.barplot(x = "country", y = "profit", data= df16,saturation=0.65)
plt.xticks(rotation = 75)
plt.title("top 5 Profitable country",fontdict=f1)
plt.show()

# %% [markdown]
# # What are the top 10 most selling Products?¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["product_name"].nunique()
# Out:
# 3788

# %%
df17 = df1.groupby("product_name")["sales"].sum().sort_values(ascending = False).head(10).reset_index()
df17
# Out:
#                                         product_name    sales
# 0                      Eldon File Cart, Single Width  31319.0
# 1                     Rogers File Cart, Single Width  22645.0
# 2                      Tenex File Cart, Single Width  20778.0
# 3                      Smead File Cart, Single Width  20775.0
# 4  Office Star Executive Leather Armchair, Adjust...  19355.0
# 5                       Fellowes Lockers, Industrial  19172.0
# 6                          Smead Lockers, Industrial  18648.0
# 7                        Hewlett Copy Machine, Color  16849.0
# 8                               Rogers Lockers, Blue  16494.0
# 9                       Fellowes Lockers, Wire Frame  16470.0

# %%
plt.figure(figsize=(15,8))
f2 = {"family":"cambria","color":"g","size":50}
f3  = {"family":"cambria","color":"k","size":40}
sns.barplot(x="product_name",y="sales",data = df17)
plt.xlabel("product_name", fontdict=f2)
plt.ylabel("selas_count",fontdict=f3)
plt.title("Growth of the Store",fontdict=f1)
plt.xticks(rotation=90,fontsize = 15)
plt.show()

# %% [markdown]
# # What is the most preferred Shipment Mode?¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["ship_mode"].unique()
# Out:
# array(['Standard Class', 'Second Class', 'Same Day', 'First Class'],
#       dtype=object)

# %%
df1["ship_mode"].value_counts()
# Out:
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: ship_mode, dtype: int64

# %%
df1["ship_mode"].value_counts().keys()
# Out:
# Index(['Standard Class', 'Second Class', 'First Class', 'Same Day'], dtype='object')

# %%
plt.pie(df1["ship_mode"].value_counts(),labels=df1["ship_mode"].value_counts().keys(),autopct="%0.1f%%",radius= 2,  textprops = {"fontsize" : 18})
plt.show()

# %% [markdown]
# # In which Region the store is giving more discount and what is the most profitable region?¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["region"].unique()
# Out:
# array(['Africa', 'Oceania', 'EMEA', 'North', 'Canada', 'Southeast Asia',
#        'Central', 'South', 'Caribbean', 'North Asia', 'East', 'West',
#        'Central Asia'], dtype=object)

# %%
df19 = df1.groupby("region")["discount","profit"].sum()
df19
# Out:
#                 discount        profit
# region
# Africa           718.800   88871.63100
# Canada             0.000   17817.39000
# Caribbean        229.420   34571.32104
# Central         1543.610  311403.98164
# Central Asia     138.200  132480.18700
# EMEA             986.100   43897.97100
# East             414.000   91522.78000
# North            459.630  194597.95252
# North Asia       113.900  165578.42100
# Oceania          534.100  121666.64200
# South            990.438  140355.76618
# Southeast Asia   851.330   17852.32900
# West             350.200  108418.44890

# %%
df19.plot(kind='bar',figsize=(16,10))
plt.title("discount vs. Profits")
plt.ylabel("In Lakhs")
# Out:
# Text(0, 0.5, 'In Lakhs')

# %% [markdown]
# # Creating only Profit/Loss Dataframe to calculate Total Profit & Loss of the superstore from 2011-2014 and the Net Profit¶

# %%
df_profit = df1[df1["profit"]>0]
df_profit.head()
# Out:
#         order_id order_date  ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040 2011-01-01 2011-06-01  Standard Class  Toby Braunhardt
# 1  IN-2011-47883 2011-01-01 2011-08-01  Standard Class      Joseph Holt
# 2   HU-2011-1220 2011-01-01 2011-05-01    Second Class    Annie Thurman
# 4  IN-2011-47883 2011-01-01 2011-08-01  Standard Class      Joseph Holt
# 5  IN-2011-47883 2011-01-01 2011-08-01  Standard Class      Joseph Holt
#
#     segment            state    country  market   region  ...  \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2  Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 4  Consumer  New South Wales  Australia    APAC  Oceania  ...
# 5  Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                             product_name  \
# 0  Office Supplies      Storage                      Tenex Lockers, Blue
# 1  Office Supplies     Supplies                 Acme Trimmer, High Speed
# 2  Office Supplies      Storage                  Tenex Box, Single Width
# 4        Furniture  Furnishings               Eldon Light Bulb, Duo Pack
# 5  Office Supplies        Paper  Eaton Computer Printout Paper, 8.5 x 11
#
#    sales  quantity  discount   profit  shipping_cost  order_priority  year
# 0  408.0         2       0.0  106.140          35.46          Medium  2011
# 1  120.0         3       0.1   36.036           9.72          Medium  2011
# 2   66.0         4       0.0   29.640           8.17            High  2011
# 4  114.0         5       0.1   37.770           4.70          Medium  2011
# 5   55.0         2       0.1   15.342           1.80          Medium  2011
#
# [5 rows x 21 columns]

# %%
df_loss = df1[df1["profit"]<0]
df_loss.head()
# Out:
#            order_id order_date  ship_date       ship_mode customer_name  \
# 3   IT-2011-3647632 2011-01-01 2011-05-01    Second Class  Eugene Moren
# 8     ID-2011-80230 2011-03-01 2011-09-01  Standard Class  Ken Lonsdale
# 10    IN-2011-65159 2011-03-01 2011-07-01    Second Class  Larry Blacks
# 11    IN-2011-65159 2011-03-01 2011-07-01    Second Class  Larry Blacks
# 14    ID-2011-80230 2011-03-01 2011-09-01  Standard Class  Ken Lonsdale
#
#         segment             state      country market          region  ...  \
# 3   Home Office         Stockholm       Sweden     EU           North  ...
# 8      Consumer          Auckland  New Zealand   APAC         Oceania  ...
# 10     Consumer  National Capital  Philippines   APAC  Southeast Asia  ...
# 11     Consumer  National Capital  Philippines   APAC  Southeast Asia  ...
# 14     Consumer          Auckland  New Zealand   APAC         Oceania  ...
#
#            category sub_category                               product_name  \
# 3   Office Supplies        Paper                Enermax Note Cards, Premium
# 8        Technology      Copiers                Hewlett Wireless Fax, Laser
# 10  Office Supplies      Storage                  Tenex Lockers, Industrial
# 11        Furniture       Tables  Chromcraft Round Table, Adjustable Height
# 14        Furniture       Chairs              Hon Rocking Chair, Set of Two
#
#     sales  quantity  discount    profit  shipping_cost  order_priority  year
# 3    45.0         3      0.50  -26.0550           4.82            High  2011
# 8   912.0         4      0.40 -319.4640         107.10             Low  2011
# 10  338.0         3      0.45 -122.8005          33.75            High  2011
# 11  211.0         1      0.55  -70.3995          21.32            High  2011
# 14  159.0         2      0.40  -95.6760          10.07             Low  2011
#
# [5 rows x 21 columns]

# %%
total_profit = df_profit["profit"].sum().round(2)
total_profit
# Out:
# 2389392.21

# %%
total_loss = df_loss["profit"].sum().round(2)
total_loss
# Out:
# -920357.39

# %%
net_worth =total_profit - total_loss
net_worth.round(2)
# Out:
# 3309749.6

# %%
df_net_profit = pd.DataFrame({"total_profit" : {0:1425420.41},
                            "total_loss" : {0:710690.23},
                            "net_worth":{0:714730.18}})

# %%
df_net_profit
# Out:
#    total_profit  total_loss  net_worth
# 0    1425420.41   710690.23  714730.18

# %% [markdown]
# # Find weighted avarage sales by region

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df_sales = df1.groupby("region")["sales"].sum().reset_index()
df_sales
# Out:
#             region      sales
# 0           Africa   538115.0
# 1           Canada    50314.0
# 2        Caribbean   251441.0
# 3          Central  1806638.0
# 4     Central Asia   389506.0
# 5             EMEA   575562.0
# 6             East   366492.0
# 7            North   790546.0
# 8       North Asia   453686.0
# 9          Oceania   625382.0
# 10           South  1031101.0
# 11  Southeast Asia   532172.0
# 12            West   424173.0

# %%
df_count = df1.groupby("region")["sales"].count().reset_index().rename(columns = {"sales":"freq"})
df_count
# Out:
#             region   freq
# 0           Africa   4448
# 1           Canada    375
# 2        Caribbean   1643
# 3          Central  10543
# 4     Central Asia   1867
# 5             EMEA   4891
# 6             East   2705
# 7            North   4520
# 8       North Asia   2121
# 9          Oceania   3238
# 10           South   6340
# 11  Southeast Asia   2926
# 12            West   3043

# %%
df_wt = df_sales.merge(df_count,on = "region")
df_wt
# Out:
#             region      sales   freq
# 0           Africa   538115.0   4448
# 1           Canada    50314.0    375
# 2        Caribbean   251441.0   1643
# 3          Central  1806638.0  10543
# 4     Central Asia   389506.0   1867
# 5             EMEA   575562.0   4891
# 6             East   366492.0   2705
# 7            North   790546.0   4520
# 8       North Asia   453686.0   2121
# 9          Oceania   625382.0   3238
# 10           South  1031101.0   6340
# 11  Southeast Asia   532172.0   2926
# 12            West   424173.0   3043

# %%
df_wt["fre_SUM"] = df_wt.sales * df_wt.freq

# %%
df_wt
# Out:
#             region      sales   freq       fre_SUM
# 0           Africa   538115.0   4448  2.393536e+09
# 1           Canada    50314.0    375  1.886775e+07
# 2        Caribbean   251441.0   1643  4.131176e+08
# 3          Central  1806638.0  10543  1.904738e+10
# 4     Central Asia   389506.0   1867  7.272077e+08
# 5             EMEA   575562.0   4891  2.815074e+09
# 6             East   366492.0   2705  9.913609e+08
# 7            North   790546.0   4520  3.573268e+09
# 8       North Asia   453686.0   2121  9.622680e+08
# 9          Oceania   625382.0   3238  2.024987e+09
# 10           South  1031101.0   6340  6.537180e+09
# 11  Southeast Asia   532172.0   2926  1.557135e+09
# 12            West   424173.0   3043  1.290758e+09

# %%
weight_avg = df_wt.fre_SUM.sum() / df_wt.freq.sum()
weight_avg
# Out:
# 870368.7723797781

# %% [markdown]
# # state wise profit of supermarket

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["state"].nunique()
# Out:
# 1094

# %%
df21 = df1.groupby("state")[["profit","sales"]].sum()
df22 = df21.sort_values(by = "profit",ascending=False)
df22.head(10)
# Out:
#                              profit     sales
# state
# England                 99907.73100  273710.0
# California              76381.38710  270615.0
# New York                74038.54860  153366.0
# New South Wales         45273.51400  145380.0
# Ile-de-France           44055.92400  188108.0
# North Rhine-Westphalia  42347.87100  135097.0
# San Salvador            35883.37700  105245.0
# Washington              33402.65170   64329.0
# Michigan                24463.18760   40062.0
# São Paulo               21878.02388   70388.0

# %% [markdown]
# # country wise profit of supermarket

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["country"].nunique()
# Out:
# 147

# %%
df23 = df1.groupby("country")[["profit","sales"]].sum()
df24 = df23.sort_values(by = "profit",ascending=False)
df24.head(10)
# Out:
#                       profit      sales
# country
# United States   286397.02170  1304166.0
# China           150683.08500   368852.0
# India           129071.83500   302511.0
# United Kingdom  111900.15000   300040.0
# France          109029.00300   526745.0
# Germany         107322.82050   389320.0
# Australia       105484.96300   516624.0
# Mexico          102818.09752   416083.0
# Spain            54390.12000   165619.0
# El Salvador      42023.24320   123814.0

# %% [markdown]
# # check state wise loss of supermarket

# %%
df22.head()
# Out:
#                      profit     sales
# state
# England          99907.7310  273710.0
# California       76381.3871  270615.0
# New York         74038.5486  153366.0
# New South Wales  45273.5140  145380.0
# Ile-de-France    44055.9240  188108.0

# %%
df25 = df22["profit"]<0

# %%
df25_loss = df22[df22["profit"]<0]
df25_loss.head(10)
# Out:
#                      profit    sales
# state
# Táchira             -0.5400     33.0
# Ayacucho            -1.3160    609.0
# Cojedes             -3.3400    114.0
# T?nh C?n Th?        -4.4103   1983.0
# Matabeleland North  -5.3250      3.0
# Kabarole            -5.4870      4.0
# Ho Chí Minh City    -5.7576  31035.0
# Tarija              -7.0160    466.0
# Lambayeque          -8.4240     32.0
# Ardahan            -10.7760     36.0

# %% [markdown]
# # country wise loss of supermarket

# %%
df24.head()
# Out:
#                      profit      sales
# country
# United States   286397.0217  1304166.0
# China           150683.0850   368852.0
# India           129071.8350   302511.0
# United Kingdom  111900.1500   300040.0
# France          109029.0030   526745.0

# %%
df26 = df24[df24["profit"]<0]
df26
# Out:
#                            profit     sales
# country
# Tajikistan             -262.86600     242.0
# Papua New Guinea       -418.60500    1786.0
# United Arab Emirates  -1036.86000     742.0
# Vietnam               -1870.23060   47572.0
# Myanmar (Burma)       -2109.25830   26341.0
# Uganda                -2426.08500    1625.0
# Turkmenistan          -3302.70900    2029.0
# Yemen                 -3706.45800    2464.0
# Haiti                 -4187.31100    9945.0
# Denmark               -4282.04700    8643.0
# Zimbabwe              -5428.78500    3767.0
# Peru                  -5507.87628   17834.0
# Kazakhstan            -7099.89600    4602.0
# Thailand              -7308.19500   41102.0
# Ireland               -7392.38100   15609.0
# Dominican Republic    -7613.49872  106487.0
# Portugal              -8703.06000    9106.0
# Lithuania             -8966.11800    3379.0
# Venezuela            -11222.71044   25533.0
# South Korea          -12792.83100   27418.0
# Philippines          -16128.22500  120135.0
# Sweden               -17519.36700   23420.0
# Panama               -17723.45248   46257.0
# Argentina            -18693.79672   47783.0
# Pakistan             -22446.64800   38967.0
# Honduras             -29482.37140   82109.0
# Netherlands          -41070.07500   59377.0
# Nigeria              -80750.71800   51552.0
# Turkey               -98447.23200   92522.0

# %%
df26.shape
# Out:
# (29, 2)

# %%
df26.plot(kind='bar',figsize=(16,10))
plt.title("Sales vs. Profits")
plt.ylabel("In Lakhs")
# Out:
# Text(0, 0.5, 'In Lakhs')

# %% [markdown]
# # What are the Highest selling and Lowest Selling Sub-Category?¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df1['sub_category'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Analyzing the product needs of Top 10 countries as per Coustomer Segment¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["segment"].unique()
# Out:
# array(['Consumer', 'Home Office', 'Corporate'], dtype=object)

# %%
df27 = df1["country"].value_counts().head(10)
df27
# Out:
# United States     9994
# Australia         2837
# France            2827
# Mexico            2644
# Germany           2065
# China             1880
# United Kingdom    1633
# Brazil            1599
# India             1555
# Indonesia         1390
# Name: country, dtype: int64

# %%
#Products by Categories consumed by Top 10 countries
plt.figure(figsize=(15,10))
plt.title("United States")
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Australia")
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("France")
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Mexico")
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Germany")
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("China")
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Brazil")
sns.set_theme(style="darkgrid")
sns.countplot(x = df1["segment"],hue=df1["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("United States")
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("India")
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["sub_category"])
##################################
plt.figure(figsize=(15,10))
plt.title("Indonesia")
sns.set_theme(style="darkgrid")
sns.countplot(x=df1["segment"],hue=df1["sub_category"])
# Out:
# <AxesSubplot:title={'center':'Indonesia'}, xlabel='segment', ylabel='count'>

# %% [markdown]
# # year wise SALES vs. PROFITS¶

# %%
df1["year"].unique()
# Out:
# array([2011, 2012, 2013, 2014], dtype=int64)

# %%
df28 = df1.groupby('year')[['sales','profit']].sum()
df28
# Out:
#           sales        profit
# year
# 2011  1378151.0  248940.81154
# 2012  1681499.0  307415.27910
# 2013  2107021.0  408512.76018
# 2014  2668457.0  504165.97046

# %%
df28.plot(kind='bar',figsize=(16,10))
plt.title("Sales vs. Profits")
plt.ylabel("In Lakhs")
# Out:
# Text(0, 0.5, 'In Lakhs')

# %% [markdown]
# # Analyzing shiping mode for each category in Super-store¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))
sns.countplot(x=df1["category"],hue=df1["ship_mode"])
# Out:
# <AxesSubplot:xlabel='category', ylabel='count'>

# %% [markdown]
# # Checking the concentration of customer segment in each market¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1["market"].unique()
# Out:
# array(['Africa', 'APAC', 'EMEA', 'EU', 'Canada', 'LATAM', 'US'],
#       dtype=object)

# %%
plt.title("APAC market")
sns.countplot(x=df1["segment"],hue=df1["category"])
plt.show()

plt.title("Africa market")
sns.countplot(x=df1["segment"],hue=df1["category"])
plt.show()


plt.title("EMEA market")
sns.countplot(x=df1["segment"],hue=df1["category"])
plt.show()


plt.title("EU market")
sns.countplot(x=df1["segment"],hue=df1["category"])
plt.show()


plt.title("Canada market")
sns.countplot(x=df1["segment"],hue=df1["category"])
plt.show()


plt.title("LATAM market")
sns.countplot(x=df1["segment"],hue=df1["category"])
plt.show()



plt.title("US market")
sns.countplot(x=df1["segment"],hue=df1["category"])
plt.show()

# %% [markdown]
# # Analyzing profits from each Category¶

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df29 = df1.groupby("category")[["profit","sales"]].sum()
df29
# Out:
#                        profit      sales
# category
# Furniture        286782.25380  2406605.0
# Office Supplies  518473.83430  2790258.0
# Technology       663778.73318  2638265.0

# %%
df29.plot(kind='bar',figsize=(16,5))
plt.ylabel("In millions")
plt.show()

# %% [markdown]
# # Analyzing profits from each Market in world¶

# %%
df30 = df1.groupby('market')[['sales','profit']].sum()
df30
# Out:
#             sales        profit
# market
# APAC    2000746.0  437577.57900
# Africa   538115.0   88871.63100
# Canada    50314.0   17817.39000
# EMEA     575562.0   43897.97100
# EU      1803099.0  372829.74150
# LATAM   1563126.0  221643.48708
# US      1304166.0  286397.02170

# %%
df30.plot(kind='bar',figsize=(16,5))
plt.ylabel("In millions")
plt.show()

# %% [markdown]
# # regional profits by segment

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df31 = df1.groupby(["region","segment"])[["profit"]].sum()
df31
# Out:
#                                   profit
# region         segment
# Africa         Consumer      47772.09900
#                Corporate     20686.96500
#                Home Office   20412.56700
# Canada         Consumer       9677.70000
#                Corporate      5036.46000
#                Home Office    3103.23000
# Caribbean      Consumer      19868.44628
#                Corporate      9188.65780
#                Home Office    5514.21696
# Central        Consumer     150540.09652
#                Corporate    101865.30866
#                Home Office   58998.57646
# Central Asia   Consumer      69196.07400
#                Corporate     41555.33800
#                Home Office   21728.77500
# EMEA           Consumer      25532.57400
#                Corporate     12499.13400
#                Home Office    5866.26300
# East           Consumer      41190.98430
#                Corporate     23622.57890
#                Home Office   26709.21680
# North          Consumer     100198.13052
#                Corporate     62393.81800
#                Home Office   32006.00400
# North Asia     Consumer      81181.61100
#                Corporate     49815.72600
#                Home Office   34581.08400
# Oceania        Consumer      62205.18000
#                Corporate     36236.56300
#                Home Office   23224.89900
# South          Consumer      74191.58704
#                Corporate     41740.74160
#                Home Office   24423.43754
# Southeast Asia Consumer      10234.69540
#                Corporate      3707.13780
#                Home Office    3910.49580
# West           Consumer      57450.60400
#                Corporate     34437.42990
#                Home Office   16530.41500

# %%
plt.figure(figsize=(14,6))
sns.barplot(data = df31, x = df1["region"], y = df1["profit"], hue = df1["segment"])
plt.xticks(rotation = 90)
plt.title("Regional profits by customer segment")
plt.show()

# %% [markdown]
# # regional sales by segment

# %%
df32 = df1.groupby(["region","segment"])[["sales"]].sum()
df32
# Out:
#                                sales
# region         segment
# Africa         Consumer     288829.0
#                Corporate    148790.0
#                Home Office  100496.0
# Canada         Consumer      26317.0
#                Corporate     14371.0
#                Home Office    9626.0
# Caribbean      Consumer     121909.0
#                Corporate     84377.0
#                Home Office   45155.0
# Central        Consumer     951781.0
#                Corporate    523414.0
#                Home Office  331443.0
# Central Asia   Consumer     195862.0
#                Corporate    116873.0
#                Home Office   76771.0
# EMEA           Consumer     290891.0
#                Corporate    180550.0
#                Home Office  104121.0
# East           Consumer     185562.0
#                Corporate    119370.0
#                Home Office   61560.0
# North          Consumer     393840.0
#                Corporate    261153.0
#                Home Office  135553.0
# North Asia     Consumer     216330.0
#                Corporate    139918.0
#                Home Office   97438.0
# Oceania        Consumer     323314.0
#                Corporate    190974.0
#                Home Office  111094.0
# South          Consumer     551020.0
#                Corporate    305163.0
#                Home Office  174918.0
# Southeast Asia Consumer     289642.0
#                Corporate    150063.0
#                Home Office   92467.0
# West           Consumer     222821.0
#                Corporate    134245.0
#                Home Office   67107.0

# %%
plt.figure(figsize=(14,6))
sns.barplot(data = df31, x = df1["region"], y = df1["sales"], hue = df1["segment"])
plt.xticks(rotation = 90)
plt.title("Regional profits by customer segment")
plt.show()

# %% [markdown]
# # profits and sales by sub-category of goods in 2014

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df33 = df1.groupby(["year","sub_category"])["profit"].sum().reset_index()
df33
# Out:
#     year sub_category      profit
# 0   2011  Accessories  15719.8606
# 1   2011   Appliances  22838.4413
# 2   2011          Art  10399.0233
# 3   2011      Binders  11447.2053
# 4   2011    Bookcases  27518.8575
# ..   ...          ...         ...
# 63  2014        Paper  20975.8306
# 64  2014       Phones  70657.6413
# 65  2014      Storage  39016.9521
# 66  2014     Supplies   7365.4090
# 67  2014       Tables -30545.9084
#
# [68 rows x 3 columns]

# %%
plt.figure(figsize=[28,12])
sns.barplot(data=df33[df33["year"] == 2014].sort_values(by='profit'), x='sub_category', y='profit').set_title("Overall profits by sub-category in 2014")
plt.show()

# %%
df34 = df1.groupby(["year","sub_category"])["sales"].sum().reset_index()
df34
# Out:
#     year sub_category     sales
# 0   2011  Accessories   92648.0
# 1   2011   Appliances   68907.0
# 2   2011          Art   63049.0
# 3   2011      Binders   60257.0
# 4   2011    Bookcases  134937.0
# ..   ...          ...       ...
# 63  2014        Paper   79627.0
# 64  2014       Phones  295662.0
# 65  2014      Storage  312252.0
# 66  2014     Supplies   74472.0
# 67  2014       Tables  100180.0
#
# [68 rows x 3 columns]

# %%
plt.figure(figsize=[28,12])
sns.barplot(data=df34[df34["year"] == 2014].sort_values(by='sales'), x='sub_category', y='sales').set_title("Overall sales by sub-category in 2014")
plt.show()

# %% [markdown]
# # Overaqll profit vs sales by sub__category in 2014

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df35 = df33[df33["year"]==2014]["profit"]/df34[df34["year"] == 2014]["sales"]
df35
# Out:
# 51    0.215117
# 52    0.439252
# 53    0.157384
# 54    0.182267
# 55    0.225815
# 56    0.137697
# 57    0.372808
# 58    0.154525
# 59    0.128578
# 60    0.122166
# 61    0.195095
# 62    0.125250
# 63    0.263426
# 64    0.238981
# 65    0.124953
# 66    0.098902
# 67   -0.304910
# dtype: float64

# %%
plt.figure(figsize=[28,12])
sns.barplot(x=df34['sub_category'], y=df35).set_title("Overall profits vs sales by sub-category in 2014")
plt.show()

# %% [markdown]
# # Most profitable category in sub-category

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df36 = df1.groupby(["category","sub_category"])[["profit"]].sum()
df36
# Out:
#                                     profit
# category        sub_category
# Furniture       Bookcases     161924.41950
#                 Chairs        141973.79750
#                 Furnishings    46967.42550
#                 Tables        -64083.38870
# Office Supplies Appliances    141680.58940
#                 Art            57953.91090
#                 Binders        72449.84600
#                 Envelopes      29601.11630
#                 Fasteners      11525.42410
#                 Labels         15010.51200
#                 Paper          59207.68270
#                 Storage       108461.48980
#                 Supplies       22583.26310
# Technology      Accessories   129626.30620
#                 Copiers       258567.54818
#                 Machines       58867.87300
#                 Phones        216717.00580

# %%
plt.figure(figsize=(13,12))
sns.barplot(data = df36, x = df1["category"],y= df1["profit"],hue = df1["sub_category"])
# Out:
# <AxesSubplot:xlabel='category', ylabel='profit'>
