# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv(r"C:\Users\Sinha Rahul\Downloads\archive (7).zip")

# %%
data1
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# # Display Top 10 row in dataset

# %%
data1.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
data1.head(-5)
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# # check last 10 ROW IN DATASET

# %%
data1.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
data1.tail(-5)
# Out:
#                                                 Address    Lot AM or PM  \
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# # check datatype in each column

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# # check describe in dataset

# %%
data1.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %% [markdown]
# # check null value in dataset

# %%
data1.isnull().values.any()
# Out:
# False

# %%
data1.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # how many row and column are there in our dataset

# %%
data1.shape
# Out:
# (10000, 14)

# %%
print("the number of row is",data1.shape[0])
print("the number of columns is",data1.shape[1])
# Out:
# the number of row is 10000
# the number of columns is 14

# %%
data1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
len(data1.columns)
# Out:
# 14

# %%
len(data1)
# Out:
# 10000

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# # Highest and lowest purchase price

# %%
data1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
data1["Purchase Price"].max()
# Out:
# 99.99

# %%
data1["Purchase Price"].min()
# Out:
# 0.0

# %% [markdown]
# # Avarge purchase price

# %%
data1["Purchase Price"].mean()
# Out:
# 50.34730200000025

# %% [markdown]
# # How many people have French "fr" as their language

# %%
data1["Language"] == "fr"
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Language, Length: 10000, dtype: bool

# %%
data1[data1["Language"] == "fr"]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 53                PSC 9431, Box 7059\nAPO AA 29285-1363  14 qD       AM
# 76    49206 Campbell Port\nNorth Cliffordshire, HI 3...  71 iu       PM
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9951                518 Brown Dam\nGarciaside, IN 33057  71 wq       AM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9980           6061 Dave Lights\nPhillipsview, UT 40500  25 Mv       AM
#
#                                            Browser Info  \
# ...

# %%
len(data1[data1["Language"] == "fr"])
# Out:
# 1097

# %%
data1[data1["Language"] == "fr"].count()
# Out:
# Address             1097
# Lot                 1097
# AM or PM            1097
# Browser Info        1097
# Company             1097
# Credit Card         1097
# CC Exp Date         1097
# CC Security Code    1097
# CC Provider         1097
# Email               1097
# Job                 1097
# IP Address          1097
# Language            1097
# Purchase Price      1097
# dtype: int64

# %% [markdown]
# # job title contains engineer

# %%
data1["Job"]
# Out:
# 0       Scientist, product/process development
# 1                            Drilling engineer
# 2                     Customer service manager
# 3                            Drilling engineer
# 4                                  Fine artist
#                          ...
# 9995                                Printmaker
# 9996                           Energy engineer
# 9997                        Veterinary surgeon
# 9998                  Local government officer
# 9999                    Embryologist, clinical
# Name: Job, Length: 10000, dtype: object

# %%
data1["Job"].str.contains("engineer")
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Job, Length: 10000, dtype: bool

# %%
data1[data1["Job"].str.contains("engineer")]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 103                480 Ronald Cape\nJohnville, MA 53644  11 wg       AM
# 193   1010 Mahoney Mills Suite 486\nWest Daniellevie...  70 Fd       AM
# ...                                                 ...    ...      ...
# 9934     52276 Smith Cliffs\nLake Vanessaview, AL 91791  40 nG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
len(data1[data1["Job"].str.contains("engineer")])
# Out:
# 531

# %%
len(data1[data1["Job"].str.contains("engineer", case = False)])
# Out:
# 984

# %% [markdown]
# # Find Email of the person with following ip address:#    132.207.160.22

# %%
data1["IP Address"]
# Out:
# 0       149.146.147.205
# 1          15.160.41.51
# 2        132.207.160.22
# 3          30.250.74.19
# 4          24.140.33.94
#              ...
# 9995      29.73.197.114
# 9996     121.133.168.51
# 9997      156.210.0.254
# 9998       55.78.26.143
# 9999    176.119.198.199
# Name: IP Address, Length: 10000, dtype: object

# %%
data1["IP Address"]== "132.207.160.22"
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: IP Address, Length: 10000, dtype: bool

# %%
data1[data1["IP Address"]== "132.207.160.22"]
# Out:
#                             Address    Lot AM or PM  \
# 2  Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
#
#                                         Browser Info  \
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                       Company   Credit Card CC Exp Date  CC Security Code  \
# 2  Simpson, Williams and Pham  675957666125       08/19               699
#
#     CC Provider                           Email                       Job  \
# 2  JCB 16 digit  amymiller@morales-harrison.com  Customer service manager
#
#        IP Address Language  Purchase Price
# 2  132.207.160.22       de            0.95

# %%
data1[data1["IP Address"]== "132.207.160.22"]["Email"]
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
data1[data1["IP Address"]== "121.133.168.51"]["Email"]
# Out:
# 9996    mary85@hotmail.com
# Name: Email, dtype: object

# %%
data1[data1["IP Address"]== "121.133.168.51"]["Job"]
# Out:
# 9996    Energy engineer
# Name: Job, dtype: object

# %% [markdown]
# # How many people have mastercard as their credit card provider and  made a  purchase  above 50?

# %%
data1["CC Provider"]
# Out:
# 0                      JCB 16 digit
# 1                        Mastercard
# 2                      JCB 16 digit
# 3                          Discover
# 4       Diners Club / Carte Blanche
#                    ...
# 9995                   JCB 15 digit
# 9996                   JCB 16 digit
# 9997                  VISA 16 digit
# 9998               American Express
# 9999                   JCB 15 digit
# Name: CC Provider, Length: 10000, dtype: object

# %%
data1["CC Provider"]=="Mastercard"
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: CC Provider, Length: 10000, dtype: bool

# %%
data1[data1["CC Provider"]=="Mastercard"]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 41    779 Sydney Keys Apt. 119\nAnthonyside, NH 2179...  21 lh       PM
# ...                                                 ...    ...      ...
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
data1[(data1["CC Provider"]=="Mastercard") & (data1["Purchase Price"]>50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
len(data1[(data1["CC Provider"]=="Mastercard") & (data1["Purchase Price"]>50)])
# Out:
# 405

# %% [markdown]
# # Find Email of the person with following Credit Card number:# 4664825258997302

# %%
data1["Credit Card"]
# Out:
# 0       6011929061123406
# 1       3337758169645356
# 2           675957666125
# 3       6011578504430710
# 4       6011456623207998
#               ...
# 9995     342945015358701
# 9996     210033169205009
# 9997    6011539787356311
# 9998     180003348082930
# 9999    4139972901927273
# Name: Credit Card, Length: 10000, dtype: int64

# %%
data1["Credit Card"]== "46648225258997302"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Credit Card, Length: 10000, dtype: bool

# %%
data1[data1["Credit Card"]== 4664825258997302]
# Out:
#                                                 Address    Lot AM or PM  \
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
#
#                                            Browser Info    Company  \
# 9992  Mozilla/5.0 (Macintosh; PPC Mac OS X 10_6_5) A...  Wells Ltd
#
#            Credit Card CC Exp Date  CC Security Code CC Provider  \
# 9992  4664825258997302       10/20               431    Discover
#
#                   Email           Job     IP Address Language  Purchase Price
# 9992  bberry@wright.net  Set designer  174.173.51.32       de           67.96

# %%
data1[data1["Credit Card"]==4664825258997302]["Email"]
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %% [markdown]
# # How Many people purchase During The Am and How Many people purchase during Pm?

# %%
data1["AM or PM"].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# # How Many people Have A credit Card That  expire In 2020

# %% [markdown]
# # Using Lamada Function

# %%
data1["CC Exp Date"]
# Out:
# 0       02/20
# 1       11/18
# 2       08/19
# 3       02/24
# 4       10/25
#         ...
# 9995    03/22
# 9996    07/25
# 9997    05/21
# 9998    11/17
# 9999    02/19
# Name: CC Exp Date, Length: 10000, dtype: object

# %%
data1["CC Exp Date"]== 2020
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: CC Exp Date, Length: 10000, dtype: bool

# %%
data1["CC Exp Date"].apply(lambda x:x.split("/")[1] == "20")
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: CC Exp Date, Length: 10000, dtype: bool

# %%
data1[data1["CC Exp Date"].apply(lambda x:x.split("/")[1] == "20")]
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 32                     Unit 3628 Box 6778\nDPO AE 72362  39 Qm       PM
# 36    9374 Skinner Common Apt. 254\nChristopherfort,...  80 Fq       PM
# 38    9671 Riley Drives Apt. 746\nPort Davidtown, TN...  15 vj       AM
# ...                                                 ...    ...      ...
# 9883        751 Petersen Groves\nLake Rebecca, NM 55875  61 tE       PM
# 9901      908 Norman Burgs\nPhillipsberg, VT 92023-9956  90 Ng       PM
# 9911  44320 Gray Centers Suite 325\nJenniferfurt, OK...  19 Bf       PM
# 9957             73556 Chase Pine\nBrucemouth, MP 73473  25 rU       PM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
#
#                                            Browser Info  \
# ...

# %%
len(data1[data1["CC Exp Date"].apply(lambda x:x.split("/")[1] == "20")])
# Out:
# 988

# %%
list = []
for email in data1["CC Exp Date"]:
    list.append(email.split("/")[1])

# %%
list
# Out:
# ['20',
#  '18',
#  '19',
#  '24',
#  '25',
#  '25',
#  '24',
#  '25',
#  '24',
#  '17',
#  '17',
#  '26',
#  '26',
#  '25',
#  '22',
#  '25',
#  '22',
#  '26',
#  '22',
#  '20',
#  '22',
#  '25',
#  '22',
#  '23',
#  '18',
#  '19',
#  '19',
#  '16',
#  '24',
#  '22',
#  '17',
#  '22',
#  '20',
#  '25',
#  '21',
#  '16',
#  '20',
#  '18',
#  '20',
#  '19',
#  '26',
#  '20',
#  '20',
#  '23',
#  '24',
#  '26',
#  '20',
#  '20',
#  '24',
#  '25',
#  '19',
#  '17',
#  '26',
#  '17',
#  '23',
#  '19',
#  '26',
#  '24',
#  '18',
#  '20',
#  '20',
#  '17',
#  '25',
#  '19',
#  '21',
#  '21',
#  '23',
#  '20',
#  '21',
#  '23',
#  '25',
#  '21',
#  '23',
#  '22',
#  '18',
#  '22',
#  '17',
#  '23',
#  '25',
#  '25',
#  '20',
#  '21',
#  '17',
#  '20',
#  '19',
#  '22',
#  '25',
#  '23',
#  '18',
#  '18',
#  '18',
#  '24',
#  '18',
#  '18',
#  '23',
#  '18',
#  '25',
#  '25',
#  '23',
#  '22',
#  '24',
#  '16',
#  '16',
#  '22',
#  '17',
#  '21',
#  '25',
#  '21',
#  '17',
#  '16',
#  '21',
# ...

# %%
uni_list = []
for item in list:
    if item not in uni_list:
        uni_list.append(item)

# %%
uni_list
# Out:
# ['20', '18', '19', '24', '25', '17', '26', '22', '23', '16', '21']

# %%
data1["year"]=list

# %%
data1.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
data1["year"].value_counts()
# Out:
# 25    1033
# 23    1010
# 21    1006
# 22     996
# 18     995
# 19     995
# 24     992
# 20     988
# 17     955
# 26     654
# 16     376
# Name: year, dtype: int64

# %% [markdown]
# # top 5 most popular email provider(e.g.gmail.com, yahoo.com,etc....)

# %% [markdown]
# # using def function

# %%
list = []
for email in data1["Email"]:
    list.append(email.split("@")[1])

# %%
len(list)
# Out:
# 10000

# %%
len(list)
# Out:
# 10000

# %%
uni_list = []
for value in list:
     if value not in uni_list:
        uni_list.append(value)

# %%
len(uni_list)
# Out:
# 3416

# %%
len(uni_list)
# Out:
# 3416

# %%
data1["com"] = list

# %%
data1.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
data1["com"].value_counts()
# Out:
# hotmail.com            1638
# yahoo.com              1616
# gmail.com              1605
# smith.com                42
# williams.com             37
#                        ...
# booker.com                1
# woods-allen.biz           1
# richards-wilson.com       1
# morris-thomas.com         1
# wade-garner.com           1
# Name: com, Length: 3416, dtype: int64

# %%
data1["com"].value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: com, dtype: int64

# %% [markdown]
# # Using Lamada Function

# %%
data1["Email"]
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
data1["Email"].apply(lambda x : x.split("@")[1])
# Out:
# 0                  yahoo.com
# 1                   reed.com
# 2       morales-harrison.com
# 3        olson-robinson.info
# 4                  gmail.com
#                 ...
# 9995         wade-garner.com
# 9996             hotmail.com
# 9997               gmail.com
# 9998                reid.net
# 9999              vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
data1["Email"].apply(lambda x : x.split("@")[1]).value_counts()
# Out:
# hotmail.com            1638
# yahoo.com              1616
# gmail.com              1605
# smith.com                42
# williams.com             37
#                        ...
# booker.com                1
# woods-allen.biz           1
# richards-wilson.com       1
# morris-thomas.com         1
# wade-garner.com           1
# Name: Email, Length: 3416, dtype: int64

# %%
data1["Email"].apply(lambda x : x.split("@")[1]).value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %% [markdown]
# # without lamabda function

# %%
data1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price', 'year', 'com'],
#       dtype='object')

# %%
 data1['Email'].str.split('@').str[1].value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %%
df1 = pd.DataFrame( data1['Email'].str.split('@').str[1].value_counts().head(5))
df1
# Out:
#               Email
# hotmail.com    1638
# yahoo.com      1616
# gmail.com      1605
# smith.com        42
# williams.com     37

# %% [markdown]
# # Check Unique Value in Dataset

# %%
data1.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price', 'year', 'com'],
#       dtype='object')

# %%
data1["AM or PM"].nunique()
# Out:
# 2

# %%
data1["AM or PM"].unique()
# Out:
# array(['PM', 'AM'], dtype=object)

# %%
data1['CC Provider'].nunique()
# Out:
# 10

# %%
data1['CC Provider'].unique()
# Out:
# array(['JCB 16 digit', 'Mastercard', 'Discover',
#        'Diners Club / Carte Blanche', 'VISA 16 digit', 'VISA 13 digit',
#        'American Express', 'Voyager', 'JCB 15 digit', 'Maestro'],
#       dtype=object)

# %%
data1['Language'].nunique()
# Out:
# 9

# %%
data1['Language'].unique()
# Out:
# array(['el', 'fr', 'de', 'es', 'ru', 'pt', 'zh', 'en', 'it'], dtype=object)

# %% [markdown]
# # Data Visualization

# %%
data1['AM or PM'].value_counts().plot(kind = "pie",ylabel = "purchases time for people",autopct="%.1f%%",radius = 1.1, textprops = {"fontsize" : 20})
plt.legend(facecolor = "y")
plt.show()

# %%
plt.figure(figsize = (20,5))
f1= {"family":"cambria","color":"r","size":40}
f2 = {"family":"cambria","color":"g","size":50}
f3  = {"family":"cambria","color":"k","size":60}
sns.countplot(x='CC Provider',data = data1)
plt.xlabel("cc provider",fontdict = f2)
plt.ylabel("count",fontdict = f3)
plt.title("cc",  fontdict = f1)
plt.show()

# %%
plt.figure(figsize = (20,9))
sns.countplot(x='CC Provider',data = data1,hue='AM or PM',saturation=0.75)
plt.show()

# %%
plt.figure(figsize = (10,10))
f1= {"family":"cambria","color":"r","size":40}
data1["Language"].value_counts().plot(kind = "pie",ylabel="languge used distrebution", autopct="%.1f%%",pctdistance=0.80, textprops = {"fontsize" : 16})
plt.legend(facecolor = "y")
plt.title("langue",  fontdict = f1)
plt.show()

# %%
plt.figure(figsize = (10,10))
data1["Language"].value_counts().plot.pie(ylabel="languge used distrebution", autopct="%.1f%%",pctdistance=0.85, textprops = {"fontsize" : 20})
centre_circle = plt.Circle((0, 0), radius = 0.68, fc ='b')
plt.gca().add_artist(centre_circle)
plt.legend(facecolor = "y")
plt.show()

# %%
plt.figure(figsize = (10,10))
data1["Language"].value_counts().plot(kind = "pie", ylabel="languge used distrebution", autopct="%.1f%%",pctdistance=0.85, textprops = {"fontsize" : 20})
centre_circle = plt.Circle((0, 0), radius = 0.75, fc ='white')
plt.gca().add_artist(centre_circle)
plt.legend(facecolor = "c")
plt.show()
